# %% [markdown]
# # Data loading and observing #

# %%
## 1. Load the dataset into a pandas DataFrame
import pandas as pd
dataset = pd.read_csv("life_expectancy.csv")
dataset.columns = dataset.columns.str.strip()

# %%
## 2. Observe the data
print(dataset.head())
print("#"*70)
print(dataset.describe())
#print(len(dataset.columns))
# Out:
#        Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan  2015  Developing            263.0             62     0.01
# 1  Afghanistan  2014  Developing            271.0             64     0.01
# 2  Afghanistan  2013  Developing            268.0             66     0.01
# 3  Afghanistan  2012  Developing            272.0             69     0.01
# 4  Afghanistan  2011  Developing            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles   BMI  ...  Total expenditure  \
# 0               71.279624         65.0     1154  19.1  ...               8.16
# 1               73.523582         62.0      492  18.6  ...               8.18
# 2               73.219243         64.0      430  18.1  ...               8.13
# 3               78.184215         67.0     2787  17.6  ...               8.52
# 4                7.097109         68.0     3013  17.2  ...               7.87
#
#    Diphtheria  HIV/AIDS         GDP  Population  thinness  1-19 years  \
# 0        65.0       0.1  584.259210  33736494.0                  17.2
# 1        62.0       0.1  612.696514    327582.0                  17.5
# 2        64.0       0.1  631.744976  31731688.0                  17.7
# 3        67.0       0.1  669.959000   3696958.0                  17.9
# 4        68.0       0.1   63.537231   2978599.0                  18.2
#
#    thinness 5-9 years  Income composition of resources  Schooling  \
# 0                17.3                            0.479       10.1
# 1                17.5                            0.476       10.0
# 2                17.7                            0.470        9.9
# 3                18.0                            0.463        9.8
# 4                18.2                            0.454        9.5
#
#    Life expectancy
# 0             65.0
# 1             59.9
# 2             59.9
# 3             59.5
# 4             59.2
#
# [5 rows x 22 columns]
# ######################################################################
#               Year  Adult Mortality  infant deaths      Alcohol  \
# count  2938.000000      2938.000000    2938.000000  2938.000000
# mean   2007.518720       164.725664      30.303948     4.546875
# std       4.613841       124.086215     117.926501     3.921946
# min    2000.000000         1.000000       0.000000     0.010000
# 25%    2004.000000        74.000000       0.000000     1.092500
# 50%    2008.000000       144.000000       3.000000     3.755000
# 75%    2012.000000       227.000000      22.000000     7.390000
# max    2015.000000       723.000000    1800.000000    17.870000
#
#        percentage expenditure  Hepatitis B        Measles          BMI  \
# count             2938.000000  2938.000000    2938.000000  2938.000000
# mean               738.251295    83.022124    2419.592240    38.381178
# std               1987.914858    22.996984   11467.272489    19.935375
# min                  0.000000     1.000000       0.000000     1.000000
# 25%                  4.685343    82.000000       0.000000    19.400000
# 50%                 64.912906    92.000000      17.000000    43.500000
# 75%                441.534144    96.000000     360.250000    56.100000
# max              19479.911610    99.000000  212183.000000    87.300000
#
#        under-five deaths        Polio  Total expenditure   Diphtheria  \
# count        2938.000000  2938.000000        2938.000000  2938.000000
# mean           42.035739    82.617767           5.924098    82.393125
# std           160.445548    23.367166           2.400770    23.655562
# min             0.000000     3.000000           0.370000     2.000000
# 25%             0.000000    78.000000           4.370000    78.000000
# 50%             4.000000    93.000000           5.755000    93.000000
# 75%            28.000000    97.000000           7.330000    97.000000
# max          2500.000000    99.000000          17.600000    99.000000
#
#           HIV/AIDS            GDP    Population  thinness  1-19 years  \
# count  2938.000000    2938.000000  2.938000e+03           2938.000000
# mean      1.742103    6611.523863  1.023085e+07              4.821886
# std       5.077785   13296.603449  5.402242e+07              4.397621
# min       0.100000       1.681350  3.400000e+01              0.100000
# 25%       0.100000     580.486996  4.189172e+05              1.600000
# 50%       0.100000    1766.947595  1.386542e+06              3.300000
# 75%       0.800000    4779.405190  4.584371e+06              7.100000
# max      50.600000  119172.741800  1.293859e+09             27.700000
#
#        thinness 5-9 years  Income composition of resources    Schooling  \
# count         2938.000000                      2938.000000  2938.000000
# mean             4.852144                         0.630362    12.009837
# std              4.485854                         0.205140     3.265139
# min              0.100000                         0.000000     0.000000
# 25%              1.600000                         0.504250    10.300000
# 50%              3.300000                         0.677000    12.300000
# 75%              7.200000                         0.772000    14.100000
# max             28.600000                         0.948000    20.700000
#
#        Life expectancy
# count      2938.000000
# mean         69.234717
# std           9.509115
# min          36.300000
# 25%          63.200000
# 50%          72.100000
# 75%          75.600000
# max          89.000000

# %%
## 3. Drop the Country column for generalisation
dataset.pop("Country")
print(dataset.head())
# Out:
#    Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0  2015  Developing            263.0             62     0.01
# 1  2014  Developing            271.0             64     0.01
# 2  2013  Developing            268.0             66     0.01
# 3  2012  Developing            272.0             69     0.01
# 4  2011  Developing            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles   BMI  under-five deaths  ...  \
# 0               71.279624         65.0     1154  19.1                 83  ...
# 1               73.523582         62.0      492  18.6                 86  ...
# 2               73.219243         64.0      430  18.1                 89  ...
# 3               78.184215         67.0     2787  17.6                 93  ...
# 4                7.097109         68.0     3013  17.2                 97  ...
#
#    Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0               8.16        65.0       0.1  584.259210  33736494.0
# 1               8.18        62.0       0.1  612.696514    327582.0
# 2               8.13        64.0       0.1  631.744976  31731688.0
# 3               8.52        67.0       0.1  669.959000   3696958.0
# 4               7.87        68.0       0.1   63.537231   2978599.0
#
#    thinness  1-19 years  thinness 5-9 years  Income composition of resources  \
# 0                  17.2                17.3                            0.479
# 1                  17.5                17.5                            0.476
# 2                  17.7                17.7                            0.470
# 3                  17.9                18.0                            0.463
# 4                  18.2                18.2                            0.454
#
#    Schooling  Life expectancy
# 0       10.1             65.0
# 1       10.0             59.9
# 2        9.9             59.9
# 3        9.8             59.5
# 4        9.5             59.2
#
# [5 rows x 21 columns]

# %%
## 4. Assign Labels
labels = dataset.loc[:,"Life expectancy"]
print(labels.head())
# Out:
# 0    65.0
# 1    59.9
# 2    59.9
# 3    59.5
# 4    59.2
# Name: Life expectancy, dtype: float64

# %%
## 5. Assign Features
features = dataset.iloc[:,:-1]
print(features.head())
#print(features.columns)
# Out:
#    Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0  2015  Developing            263.0             62     0.01
# 1  2014  Developing            271.0             64     0.01
# 2  2013  Developing            268.0             66     0.01
# 3  2012  Developing            272.0             69     0.01
# 4  2011  Developing            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles   BMI  under-five deaths  \
# 0               71.279624         65.0     1154  19.1                 83
# 1               73.523582         62.0      492  18.6                 86
# 2               73.219243         64.0      430  18.1                 89
# 3               78.184215         67.0     2787  17.6                 93
# 4                7.097109         68.0     3013  17.2                 97
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1   58.0               8.18        62.0       0.1  612.696514    327582.0
# 2   62.0               8.13        64.0       0.1  631.744976  31731688.0
# 3   67.0               8.52        67.0       0.1  669.959000   3696958.0
# 4   68.0               7.87        68.0       0.1   63.537231   2978599.0
#
#    thinness  1-19 years  thinness 5-9 years  Income composition of resources  \
# 0                  17.2                17.3                            0.479
# 1                  17.5                17.5                            0.476
# 2                  17.7                17.7                            0.470
# 3                  17.9                18.0                            0.463
# 4                  18.2                18.2                            0.454
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5

# %% [markdown]
# # Data Preprocessing #

# %%
## 6. Apply one-hot-encoding on all the categorical columns
features = pd.get_dummies(features)
print(features.head())
print(features.columns.tolist())
# Out:
#    Year  Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 0  2015            263.0             62     0.01               71.279624
# 1  2014            271.0             64     0.01               73.523582
# 2  2013            268.0             66     0.01               73.219243
# 3  2012            272.0             69     0.01               78.184215
# 4  2011            275.0             71     0.01                7.097109
#
#    Hepatitis B  Measles   BMI  under-five deaths  Polio  ...  Diphtheria  \
# 0         65.0     1154  19.1                 83    6.0  ...        65.0
# 1         62.0      492  18.6                 86   58.0  ...        62.0
# 2         64.0      430  18.1                 89   62.0  ...        64.0
# 3         67.0     2787  17.6                 93   67.0  ...        67.0
# 4         68.0     3013  17.2                 97   68.0  ...        68.0
#
#    HIV/AIDS         GDP  Population  thinness  1-19 years  thinness 5-9 years  \
# 0       0.1  584.259210  33736494.0                  17.2                17.3
# 1       0.1  612.696514    327582.0                  17.5                17.5
# 2       0.1  631.744976  31731688.0                  17.7                17.7
# 3       0.1  669.959000   3696958.0                  17.9                18.0
# 4       0.1   63.537231   2978599.0                  18.2                18.2
#
#    Income composition of resources  Schooling  Status_Developed  \
# 0                            0.479       10.1             False
# 1                            0.476       10.0             False
# 2                            0.470        9.9             False
# 3                            0.463        9.8             False
# 4                            0.454        9.5             False
#
#    Status_Developing
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
#
# [5 rows x 21 columns]
# ['Year', 'Adult Mortality', 'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure', 'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years', 'thinness 5-9 years', 'Income composition of resources', 'Schooling', 'Status_Developed', 'Status_Developing']

# %%
## Identify redundant features
import seaborn as sns
sns.heatmap(features.corr(), annot=False, cmap="coolwarm")
# Out:
# <Axes: >

# %%
## Drop Collinear features
features = features.drop(columns=[
    'percentage expenditure', 
    'infant deaths', 
    'thinness 5-9 years'
])
print(features.columns.tolist())
# Out:
# ['Year', 'Adult Mortality', 'Alcohol', 'Hepatitis B', 'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure', 'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years', 'Income composition of resources', 'Schooling', 'Status_Developed', 'Status_Developing']

# %%
## 7. Split the data
from sklearn.model_selection import train_test_split
features_train, features_test, labels_train, labels_test = train_test_split(features, labels, test_size=0.2, train_size=0.8, random_state=42)

# %%
## 8. and 9. Standardize/Normalize numerical features
from sklearn.compose import ColumnTransformer as ct
from sklearn.preprocessing import MinMaxScaler

### Get the numerical column names
numeric_columns = features.select_dtypes(include=['float64', 'int64'])
numeric_column_names = numeric_columns.columns.tolist()

### Define the scaler and which columns to act on
transformers = [( "normalize_nums", 
                MinMaxScaler(feature_range=(0, 1), copy=False),  
                numeric_column_names
                )]
normaliser_ct = ct( transformers,        
                    remainder='passthrough'
                    )

### Normalise the features
features_train_scaled = normaliser_ct.fit_transform(features_train)
features_test_scaled = normaliser_ct.transform(features_test)

### Visualise the normalised data
features_train_scaled_df = pd.DataFrame(features_train_scaled, columns=features.columns.tolist())
print(features_train_scaled_df.head())
# Out:
#        Year  Adult Mortality   Alcohol  Hepatitis B   Measles       BMI  \
# 0  0.466667         0.173130  0.304624     0.969388  0.000000  0.280559
# 1  0.066667         0.209141  0.219653     0.928571  0.000000  0.240978
# 2  0.733333         0.196676  0.602312     1.000000  0.000000  0.501746
# 3  0.866667         0.016620  0.073988     0.989796  0.000075  0.674040
# 4  0.133333         0.130194  0.006936     1.000000  0.000000  0.309662
#
#    under-five deaths     Polio  Total expenditure  Diphtheria  HIV/AIDS  \
# 0             0.0000  0.989583           0.220012    0.989691  0.009901
# 1             0.0000  0.916667           0.273659    0.072165  0.013861
# 2             0.0000  1.000000           0.417722    1.000000  0.000000
# 3             0.0012  0.989583           0.398433    0.989691  0.000000
# 4             0.0000  1.000000           0.165763    0.948454  0.000000
#
#         GDP  Population  thinness  1-19 years  \
# 0  0.026871    0.000376              0.289855
# 1  0.010947    0.000343              0.336957
# 2  0.015249    0.001072              0.152174
# 3  0.036263    0.000861              0.228261
# 4  0.145513    0.001072              0.239130
#
#    Income composition of resources  Schooling  Status_Developed  \
# 0                         0.635021   0.574879               0.0
# 1                         0.592827   0.531401               0.0
# 2                         0.773207   0.623188               0.0
# 3                         0.759494   0.710145               0.0
# 4                         0.864979   0.642512               0.0
#
#    Status_Developing
# 0                1.0
# 1                1.0
# 2                1.0
# 3                1.0
# 4                1.0

# %% [markdown]
# # Building the model #

# %%
## 11. Create instance of a Sequential Model
from tensorflow.keras.models import Sequential
my_model = Sequential()

# %%
## 12. and 13. Create and add the input layer
from tensorflow.keras.layers import InputLayer
my_model.add(
  InputLayer(
    shape = (features.shape[1], ),
    name = "Input_Layer"
    ) 
  )

# %%
## 14. Add hidden dense layer(s)
from tensorflow.keras.layers import Dense
from tensorflow.keras import regularizers
from tensorflow.keras import activations

my_model.add(
  Dense(
    128,
    activation='relu',
    use_bias=True,
    kernel_regularizer=regularizers.l1(0.01),
    name = "Hidden_Layer1"
    )
)

my_model.add(
  Dense(
    64,
    activation='relu',
    use_bias=True,
    kernel_regularizer=regularizers.l1(0.001),
    name = "Hidden_Layer2"
    )
)

# %%
## 15. Add output dense layer
my_model.add(
  Dense(
    1,
    activation='linear',
    use_bias=True,
    kernel_regularizer=regularizers.l1(0.001),
    name = "Output_Layer"
    )
)

# %%
## 16. Print Model summary
print(my_model.summary())
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden_Layer1 (Dense)           │ (None, 128)            │         2,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_Layer2 (Dense)           │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_Layer (Dense)            │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,753 (42.00 KB)
#  Trainable params: 10,753 (42.00 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# # Initializing the optimizer and compiling the model #

# %%
## 17. Create Optimizer
from tensorflow.keras.optimizers import Adam
my_optimizer = Adam(learning_rate=0.01)

# %%
## 18. Compile model
from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsoluteError
my_model.compile(
    optimizer = my_optimizer,
    loss = 'mse',
    metrics = [MeanAbsoluteError(), RootMeanSquaredError()],
)

# %% [markdown]
# # Fit and evaluate model #

# %%
## Add callbacks
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(patience=20, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(factor=0.50, patience=5)

# %%
## 19. Train model 
history = my_model.fit(
              x = features_train_scaled,
              y = labels_train,
              batch_size = 2,
              epochs = 80,
              verbose = 1,
              shuffle = True,
              validation_data = (features_test_scaled, labels_test),
              callbacks=[early_stop, reduce_lr]
              )
# Out:
# Epoch 1/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 260.2956 - mean_absolute_error: 9.2460 - root_mean_squared_error: 13.9187 - val_loss: 17.9186 - val_mean_absolute_error: 2.9543 - val_root_mean_squared_error: 3.9907 - learning_rate: 0.0100
# Epoch 2/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 29.3436 - mean_absolute_error: 4.0589 - root_mean_squared_error: 5.2216 - val_loss: 16.6049 - val_mean_absolute_error: 2.8079 - val_root_mean_squared_error: 3.8200 - learning_rate: 0.0100
# Epoch 3/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 26.3744 - mean_absolute_error: 3.8115 - root_mean_squared_error: 4.9282 - val_loss: 15.4221 - val_mean_absolute_error: 2.7520 - val_root_mean_squared_error: 3.6608 - learning_rate: 0.0100
# Epoch 4/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 25.7769 - mean_absolute_error: 3.7478 - root_mean_squared_error: 4.8662 - val_loss: 15.4218 - val_mean_absolute_error: 2.7903 - val_root_mean_squared_error: 3.6614 - learning_rate: 0.0100
# Epoch 5/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 23.1509 - mean_absolute_error: 3.5751 - root_mean_squared_error: 4.5910 - val_loss: 35.8044 - val_mean_absolute_error: 4.9834 - val_root_mean_squared_error: 5.8214 - learning_rate: 0.0100
# Epoch 6/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 25.7866 - mean_absolute_error: 3.7653 - root_mean_squared_error: 4.8799 - val_loss: 12.8346 - val_mean_absolute_error: 2.4469 - val_root_mean_squared_error: 3.3191 - learning_rate: 0.0100
# Epoch 7/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 18.6242 - mean_absolute_error: 3.1758 - root_mean_squared_error: 4.0956 - val_loss: 16.2599 - val_mean_absolute_error: 2.9072 - val_root_mean_squared_error: 3.8043 - learning_rate: 0.0100
# Epoch 8/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 18.0837 - mean_absolute_error: 3.1349 - root_mean_squared_error: 4.0415 - val_loss: 13.4555 - val_mean_absolute_error: 2.6098 - val_root_mean_squared_error: 3.4260 - learning_rate: 0.0100
# Epoch 9/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 21.0729 - mean_absolute_error: 3.4292 - root_mean_squared_error: 4.3966 - val_loss: 15.6276 - val_mean_absolute_error: 2.8003 - val_root_mean_squared_error: 3.7388 - learning_rate: 0.0100
# Epoch 10/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 19.1476 - mean_absolute_error: 3.2315 - root_mean_squared_error: 4.1783 - val_loss: 32.6407 - val_mean_absolute_error: 4.8267 - val_root_mean_squared_error: 5.5662 - learning_rate: 0.0100
# Epoch 11/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 18.3790 - mean_absolute_error: 3.1107 - root_mean_squared_error: 4.0885 - val_loss: 25.0546 - val_mean_absolute_error: 4.0526 - val_root_mean_squared_error: 4.8380 - learning_rate: 0.0100
# Epoch 12/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 14.7349 - mean_absolute_error: 2.7753 - root_mean_squared_error: 3.6200 - val_loss: 11.7297 - val_mean_absolute_error: 2.3871 - val_root_mean_squared_error: 3.1886 - learning_rate: 0.0050
# Epoch 13/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 13.9899 - mean_absolute_error: 2.6756 - root_mean_squared_error: 3.5232 - val_loss: 12.3023 - val_mean_absolute_error: 2.5076 - val_root_mean_squared_error: 3.2825 - learning_rate: 0.0050
# Epoch 14/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 14.5683 - mean_absolute_error: 2.7209 - root_mean_squared_error: 3.6087 - val_loss: 14.0147 - val_mean_absolute_error: 2.7440 - val_root_mean_squared_error: 3.5347 - learning_rate: 0.0050
# Epoch 15/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 13.6538 - mean_absolute_error: 2.6551 - root_mean_squared_error: 3.4831 - val_loss: 11.2122 - val_mean_absolute_error: 2.2761 - val_root_mean_squared_error: 3.1206 - learning_rate: 0.0050
# Epoch 16/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 13.5028 - mean_absolute_error: 2.6179 - root_mean_squared_error: 3.4670 - val_loss: 11.3268 - val_mean_absolute_error: 2.2990 - val_root_mean_squared_error: 3.1415 - learning_rate: 0.0050
# Epoch 17/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 13.6136 - mean_absolute_error: 2.6279 - root_mean_squared_error: 3.4847 - val_loss: 20.9319 - val_mean_absolute_error: 3.6976 - val_root_mean_squared_error: 4.4170 - learning_rate: 0.0050
# Epoch 18/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 13.4715 - mean_absolute_error: 2.6063 - root_mean_squared_error: 3.4685 - val_loss: 14.7493 - val_mean_absolute_error: 2.8813 - val_root_mean_squared_error: 3.6539 - learning_rate: 0.0050
# Epoch 19/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 14.0330 - mean_absolute_error: 2.6938 - root_mean_squared_error: 3.5481 - val_loss: 14.3910 - val_mean_absolute_error: 2.8579 - val_root_mean_squared_error: 3.6039 - learning_rate: 0.0050
# Epoch 20/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 13.7813 - mean_absolute_error: 2.6150 - root_mean_squared_error: 3.5143 - val_loss: 17.2627 - val_mean_absolute_error: 3.2384 - val_root_mean_squared_error: 3.9839 - learning_rate: 0.0050
# Epoch 21/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 13.4858 - mean_absolute_error: 2.5574 - root_mean_squared_error: 3.4675 - val_loss: 10.6511 - val_mean_absolute_error: 2.2474 - val_root_mean_squared_error: 3.0483 - learning_rate: 0.0025
# Epoch 22/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 12.2247 - mean_absolute_error: 2.4544 - root_mean_squared_error: 3.2949 - val_loss: 10.4234 - val_mean_absolute_error: 2.2173 - val_root_mean_squared_error: 3.0133 - learning_rate: 0.0025
# Epoch 23/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 12.0038 - mean_absolute_error: 2.4126 - root_mean_squared_error: 3.2630 - val_loss: 11.9964 - val_mean_absolute_error: 2.4922 - val_root_mean_squared_error: 3.2653 - learning_rate: 0.0025
# Epoch 24/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 12.6477 - mean_absolute_error: 2.5016 - root_mean_squared_error: 3.3615 - val_loss: 11.1269 - val_mean_absolute_error: 2.3315 - val_root_mean_squared_error: 3.1340 - learning_rate: 0.0025
# Epoch 25/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 12.2250 - mean_absolute_error: 2.4219 - root_mean_squared_error: 3.3031 - val_loss: 10.7225 - val_mean_absolute_error: 2.3030 - val_root_mean_squared_error: 3.0707 - learning_rate: 0.0025
# Epoch 26/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 11.6255 - mean_absolute_error: 2.3873 - root_mean_squared_error: 3.2092 - val_loss: 10.3663 - val_mean_absolute_error: 2.2323 - val_root_mean_squared_error: 3.0137 - learning_rate: 0.0025
# Epoch 27/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 13.4861 - mean_absolute_error: 2.5876 - root_mean_squared_error: 3.4893 - val_loss: 10.3175 - val_mean_absolute_error: 2.1940 - val_root_mean_squared_error: 3.0072 - learning_rate: 0.0025
# Epoch 28/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 12.5282 - mean_absolute_error: 2.5162 - root_mean_squared_error: 3.3524 - val_loss: 10.5136 - val_mean_absolute_error: 2.1954 - val_root_mean_squared_error: 3.0422 - learning_rate: 0.0025
# Epoch 29/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 12.5845 - mean_absolute_error: 2.5326 - root_mean_squared_error: 3.3640 - val_loss: 10.0518 - val_mean_absolute_error: 2.1624 - val_root_mean_squared_error: 2.9664 - learning_rate: 0.0025
# Epoch 30/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 12.5936 - mean_absolute_error: 2.5125 - root_mean_squared_error: 3.3664 - val_loss: 11.1723 - val_mean_absolute_error: 2.3945 - val_root_mean_squared_error: 3.1523 - learning_rate: 0.0025
# Epoch 31/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 13.1732 - mean_absolute_error: 2.5568 - root_mean_squared_error: 3.4494 - val_loss: 11.1069 - val_mean_absolute_error: 2.3462 - val_root_mean_squared_error: 3.1423 - learning_rate: 0.0025
# Epoch 32/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 12.1473 - mean_absolute_error: 2.4962 - root_mean_squared_error: 3.3039 - val_loss: 12.1350 - val_mean_absolute_error: 2.5120 - val_root_mean_squared_error: 3.3073 - learning_rate: 0.0025
# Epoch 33/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 11.7332 - mean_absolute_error: 2.4587 - root_mean_squared_error: 3.2441 - val_loss: 10.7572 - val_mean_absolute_error: 2.3057 - val_root_mean_squared_error: 3.0958 - learning_rate: 0.0025
# Epoch 34/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 12.7469 - mean_absolute_error: 2.5614 - root_mean_squared_error: 3.3987 - val_loss: 10.7465 - val_mean_absolute_error: 2.2823 - val_root_mean_squared_error: 3.0964 - learning_rate: 0.0025
# Epoch 35/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 11.1518 - mean_absolute_error: 2.3416 - root_mean_squared_error: 3.1588 - val_loss: 9.9500 - val_mean_absolute_error: 2.1593 - val_root_mean_squared_error: 2.9671 - learning_rate: 0.0012
# Epoch 36/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 12.1767 - mean_absolute_error: 2.4699 - root_mean_squared_error: 3.3163 - val_loss: 10.5003 - val_mean_absolute_error: 2.2791 - val_root_mean_squared_error: 3.0586 - learning_rate: 0.0012
# Epoch 37/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 11.2944 - mean_absolute_error: 2.3668 - root_mean_squared_error: 3.1840 - val_loss: 9.7763 - val_mean_absolute_error: 2.1372 - val_root_mean_squared_error: 2.9387 - learning_rate: 0.0012
# Epoch 38/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 11.0616 - mean_absolute_error: 2.3188 - root_mean_squared_error: 3.1445 - val_loss: 9.9918 - val_mean_absolute_error: 2.1727 - val_root_mean_squared_error: 2.9762 - learning_rate: 0.0012
# Epoch 39/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 12.2085 - mean_absolute_error: 2.4462 - root_mean_squared_error: 3.3240 - val_loss: 10.3197 - val_mean_absolute_error: 2.2379 - val_root_mean_squared_error: 3.0311 - learning_rate: 0.0012
# Epoch 40/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 11.5180 - mean_absolute_error: 2.3620 - root_mean_squared_error: 3.2210 - val_loss: 10.8368 - val_mean_absolute_error: 2.3512 - val_root_mean_squared_error: 3.1153 - learning_rate: 0.0012
# Epoch 41/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 11.6226 - mean_absolute_error: 2.4250 - root_mean_squared_error: 3.2375 - val_loss: 10.2399 - val_mean_absolute_error: 2.2266 - val_root_mean_squared_error: 3.0184 - learning_rate: 0.0012
# Epoch 42/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 11.1560 - mean_absolute_error: 2.3549 - root_mean_squared_error: 3.1637 - val_loss: 9.8811 - val_mean_absolute_error: 2.1670 - val_root_mean_squared_error: 2.9595 - learning_rate: 0.0012
# Epoch 43/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 11.1587 - mean_absolute_error: 2.3526 - root_mean_squared_error: 3.1673 - val_loss: 10.3056 - val_mean_absolute_error: 2.2489 - val_root_mean_squared_error: 3.0307 - learning_rate: 6.2500e-04
# Epoch 44/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 10.9497 - mean_absolute_error: 2.3155 - root_mean_squared_error: 3.1329 - val_loss: 10.1471 - val_mean_absolute_error: 2.2194 - val_root_mean_squared_error: 3.0047 - learning_rate: 6.2500e-04
# Epoch 45/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 11.2679 - mean_absolute_error: 2.3534 - root_mean_squared_error: 3.1834 - val_loss: 10.1862 - val_mean_absolute_error: 2.2195 - val_root_mean_squared_error: 3.0113 - learning_rate: 6.2500e-04
# Epoch 46/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 11.0472 - mean_absolute_error: 2.3140 - root_mean_squared_error: 3.1468 - val_loss: 10.4276 - val_mean_absolute_error: 2.2724 - val_root_mean_squared_error: 3.0517 - learning_rate: 6.2500e-04
# Epoch 47/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 10.9818 - mean_absolute_error: 2.3268 - root_mean_squared_error: 3.1392 - val_loss: 9.8402 - val_mean_absolute_error: 2.1631 - val_root_mean_squared_error: 2.9542 - learning_rate: 6.2500e-04
# Epoch 48/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 11.3694 - mean_absolute_error: 2.3407 - root_mean_squared_error: 3.1983 - val_loss: 9.8517 - val_mean_absolute_error: 2.1663 - val_root_mean_squared_error: 2.9565 - learning_rate: 3.1250e-04
# Epoch 49/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 12.0827 - mean_absolute_error: 2.3761 - root_mean_squared_error: 3.2972 - val_loss: 9.8129 - val_mean_absolute_error: 2.1553 - val_root_mean_squared_error: 2.9501 - learning_rate: 3.1250e-04
# Epoch 50/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 10.6501 - mean_absolute_error: 2.2626 - root_mean_squared_error: 3.0872 - val_loss: 9.8946 - val_mean_absolute_error: 2.1710 - val_root_mean_squared_error: 2.9640 - learning_rate: 3.1250e-04
# Epoch 51/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 11.2281 - mean_absolute_error: 2.3160 - root_mean_squared_error: 3.1786 - val_loss: 9.8452 - val_mean_absolute_error: 2.1654 - val_root_mean_squared_error: 2.9558 - learning_rate: 3.1250e-04
# Epoch 52/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 10.6113 - mean_absolute_error: 2.2577 - root_mean_squared_error: 3.0797 - val_loss: 9.8725 - val_mean_absolute_error: 2.1707 - val_root_mean_squared_error: 2.9602 - learning_rate: 3.1250e-04
# Epoch 53/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 10.6059 - mean_absolute_error: 2.2824 - root_mean_squared_error: 3.0801 - val_loss: 9.8072 - val_mean_absolute_error: 2.1590 - val_root_mean_squared_error: 2.9495 - learning_rate: 1.5625e-04
# Epoch 54/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 10.6796 - mean_absolute_error: 2.2745 - root_mean_squared_error: 3.0918 - val_loss: 10.0278 - val_mean_absolute_error: 2.2018 - val_root_mean_squared_error: 2.9867 - learning_rate: 1.5625e-04
# Epoch 55/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 10.5503 - mean_absolute_error: 2.2478 - root_mean_squared_error: 3.0697 - val_loss: 9.8682 - val_mean_absolute_error: 2.1714 - val_root_mean_squared_error: 2.9600 - learning_rate: 1.5625e-04
# Epoch 56/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 10.0249 - mean_absolute_error: 2.1941 - root_mean_squared_error: 2.9774 - val_loss: 10.0570 - val_mean_absolute_error: 2.2094 - val_root_mean_squared_error: 2.9917 - learning_rate: 1.5625e-04
# Epoch 57/80
# 1175/1175 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 11.1224 - mean_absolute_error: 2.2968 - root_mean_squared_error: 3.1608 - val_loss: 10.0602 - val_mean_absolute_error: 2.2117 - val_root_mean_squared_error: 2.9922 - learning_rate: 1.5625e-04

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss [MSE]')
plt.title('Loss over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
## 20. Evaluate Model
res_mse, res_mae, res_rmse = my_model.evaluate(
                                  x = features_test_scaled,
                                  y = labels_test,
                                  batch_size = 2,
                                  verbose = 0
                                  )

print(f"RMSE = {res_rmse}, MAE = {res_mae}")
# Out:
# RMSE = 2.9386987686157227, MAE = 2.1372010707855225

# %%
import seaborn as sns

y_pred = my_model.predict(features_test_scaled)
sns.histplot(labels_test, color='blue', label='Actual', kde=True)
sns.histplot(y_pred.flatten(), color='orange', label='Predicted', kde=True)
plt.legend()
plt.title("Life Expectancy: Actual vs Predicted Distribution")
plt.show()
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
